# %%
from tqdm import tqdm

import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt


import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import StratifiedShuffleSplit
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix, f1_score, precision_score, recall_score
import cytoflow as flow
import torch
from collections import Counter

# %% [markdown]
# ### Pre Processing

# %% [markdown]
# Using the data set from (https://github.com/CaRniFeXeR/python4FCM_Examples/ ) and following the preprocessing steps using the customised python package cytoflow, the event matrix was created as a time series of data matrix for number of samples at a given time (rows) for a given marker (columns). The event matrix and markers are the required preprocessing from the paper: Automated identification of cell populations in flow cytometry data.  We deviate from the processing within the github by not limiting any of the time series

# %%
basepath = "./data/"
tube1 = flow.Tube(file = basepath + '494.csv')
ex = flow.ImportOp(tubes = [tube1]).apply()

cd19_thresh = flow.ThresholdOp(name = "CD19pos",channel = 'CD19', threshold = 1.5)
ex2 = cd19_thresh.apply(ex)

human_conditions = flow.BulkConditionOp(conditions_csv_path =  basepath + '494_labels.csv',
                                      combine_order = ["syto", "singlets", "intact","cd19", "blast"],
                                      combined_conditions_name="human_gt",
                                      combined_condition_default ="other")

ex3 = human_conditions.apply(ex2)

# %% [markdown]
# ex3.data is a pandas data frame, thanks to the python package cytoflow. The target for predicition is the manual gating which is the last column in the data fram "human_gt". There are 6 options. ['blast', 'cd19', 'intact', 'other', 'singlets', 'syto']
#
# the next steps for preprocessing is to drop the other labels and only retain the manual gating and label encode the manual gating with
#     Label Mapping: {'blast': 0, 'cd19': 1, 'intact': 2, 'other': 3, 'singlets': 4, 'syto': 5}

# %%
df = ex3.data 

df.drop(["syto", "singlets", "intact","cd19", "blast", "CD19pos", "index", "allevents","erythropoiesis", "cd20"], axis=1, inplace= True)
# Initialize LabelEncoder
label_encoder = LabelEncoder()

# Encode the categorical column
df['human_gt'] = label_encoder.fit_transform(df['human_gt'])

# Separate features and labels
X = df.drop('human_gt', axis=1).values
y = df['human_gt'].values

label_mapping = dict(zip(label_encoder.classes_, range(len(label_encoder.classes_))))

# %% [markdown]
# X is a numpy array of shape (83411,12) and y is a numpy array of size (83411,) for the CNN we need to shape X into an array of (83411,1,12) this is the shape needed for 1D convolution, it retains the flow cytometry data for a given point in time this way.

# %%
X = X.reshape(83411,1,12)
X.shape
# Out:
# (83411, 1, 12)

# %% [markdown]
# ### Model Creation
#
# We now move onto intializing weights, the 1D CNN, evaluation metrics and epochs

# %%
"""
Initialise weights of given module using Kaiming Normal initialisation for linear and convolutional layers, and zeros for bias.
"""

def init_weights(module):
    if isinstance(module, (nn.Linear, nn.Conv2d)):
        nn.init.kaiming_normal_(module.weight, mode="fan_in", nonlinearity="relu")
        if module.bias is not None:
            nn.init.zeros_(module.bias)

# %%
class BasicCNN2(nn.Module):
    """
    Simple CNN model
    """
    def __init__(self, dropout) -> None:
        super().__init__()
        self.layer1 = nn.Sequential(
            nn.Conv1d(1, 64, kernel_size=3),
            nn.ReLU(),
            nn.Dropout(dropout),
            nn.MaxPool1d(2))
        self.layer2 = nn.Flatten()
        self.layer3 = nn.Linear(320, 6)

    def forward(self, x):
        out = self.layer1(x)
        out = self.layer2(out)
        out = self.layer3(out)
        return out

# %%
splitter = StratifiedShuffleSplit(n_splits=1, test_size=0.2, random_state=42)

for train_idx, test_idx in splitter.split(X, y):
    X_train, X_test = X[train_idx], X[test_idx]
    y_train, y_test = y[train_idx], y[test_idx]
    
    print(X_train.shape)
# Out:
# (66728, 1, 12)

# %%
from collections import Counter
class_counts_dict = dict(Counter(y_train))

print(class_counts_dict)
# Out:
# {1: 3367, 0: 27339, 2: 31330, 3: 2371, 5: 1630, 4: 691}

# %%
X_train, X_test = torch.tensor(X_train, dtype=torch.float32), torch.tensor(X_test, dtype=torch.float32) #Just use float 32
y_train, y_test = torch.tensor(y_train), torch.tensor(y_test)

# %%
def compute_acc_metrics(y_true, y_pred):
    acc = accuracy_score(y_true, y_pred)
    f1 = f1_score(y_true, y_pred, average='weighted')
    precision = precision_score(y_true, y_pred, average='weighted')
    recall = recall_score(y_true, y_pred, average='weighted')
    return {"Accuracy": acc, "F1 Score": f1, "Precision": precision, "Recall": recall}

def evaluation_metrics(y_true: np.ndarray, y_preds: np.ndarray):
    conf_matrix = confusion_matrix(y_true, y_preds)
    accuracy, f1, precision, recall = (
        accuracy_score(y_true, y_preds),
        f1_score(y_true, y_preds, zero_division=0.0, average="macro"),
        precision_score(y_true, y_preds, zero_division=0.0, average="macro"),
        recall_score(y_true, y_preds, zero_division=0.0, average="macro"),
    )
    return {
        "accuracy": accuracy,
        "f1_score": f1,
        "precision": precision,
        "recall": recall,
    }, conf_matrix


@torch.inference_mode()
def perform_inference(model, X, y, device: str, loss_fn=None):
    """
    Perform inference on given dataset using given model on the specified device. If loss_fn is provided, it also
    computes the loss and returns [y_preds, y_true, losses].
    """
    model.eval()  # Set the model to evaluation mode, this disables training specific operations such as dropout and batch normalization
    y_preds = []
    y_true = []
    losses = []
    
    X,y = X.to(device), y.to(device)
    
    y = y.long()
    print("[inference.py]: Running inference...")
    
    outputs = model(X) 

        # Compute loss
    loss = loss_fn(outputs, y)

        # Compute metrics    
    preds = outputs.argmax(dim=1)
        
    y_preds.append(preds.cpu().numpy())
    y_true.append(y.cpu().numpy())
    losses.append(loss.item()) 
        
    # Compute average loss for the epoch
    loss_val = np.mean(losses)
        
    model.train()  # Set the model back to training mode
    y_true, y_preds = np.concatenate(y_true), np.concatenate(y_preds)
    return y_true, y_preds, loss_val if losses else None

# %%
n_epochs = 400
best_loss_val = float("inf")
epoch_metrics = {}
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
model = BasicCNN2(dropout=0.3).to(device)
class_counts = np.bincount(y_train.numpy()) 
class_weights = 1. / torch.tensor(class_counts, dtype=torch.float32).to(device)
optimiser = optim.Adam(model.parameters(), lr=0.001)
loss_fn = nn.CrossEntropyLoss(weight=class_weights).to(device)
print(model)

total_acc=[]
total_pre=[]
total_rec=[]
total_f1=[]
total_loss =[]
val_total_acc = []
val_total_pre = []
val_total_rec = []
val_total_f1 = []
val_total_loss = []
for epoch in range(n_epochs):
    model.train()  
    
    # Initialize lists to store metrics
    losses = []
    y_preds = []
    y_trained = []
    inputs, labels = X_train, y_train 
    labels = labels.long()
    
    outputs = model(inputs) 

    # Compute loss
    loss = loss_fn(outputs, labels)

    # Compute gradients
    loss.backward()
    optimiser.step() 
    optimiser.zero_grad(set_to_none=True) 

    # Compute metrics    
    preds = outputs.argmax(dim=1)
    
    metrics = compute_acc_metrics(labels, preds)
    total_acc.append(metrics["Accuracy"])
    total_pre.append(metrics["Precision"])
    total_rec.append(metrics["Recall"])
    total_f1.append(metrics["F1 Score"])
    total_loss.append(loss.item())

    preds = outputs.argmax(dim=1)  
    y_preds.append(preds.cpu().numpy())
    y_trained.append(labels.cpu().numpy())
    losses.append(loss.item()) 
    
# Compute average loss for the epoch
    loss_train = np.mean(losses)
    
# Flatten predictions and labels for evaluation
    y_trained = np.concatenate(y_trained)
    y_preds = np.concatenate(y_preds)
    if epoch % 1 == 0:
        print(f"Epoch {epoch} - Loss: {loss}")
        print(metrics)
       
       
    train_metrics, train_conf_matrix = evaluation_metrics(y_train, y_preds)

    y_val, y_preds_val, loss_val = perform_inference(model, X_test, y_test, device, loss_fn)
    val_metrics, val_conf_matrix = evaluation_metrics(y_val, y_preds_val)     

    val_total_acc.append(val_metrics["accuracy"])
    val_total_pre.append(val_metrics["precision"])
    val_total_rec.append(val_metrics["recall"])
    val_total_f1.append(val_metrics["f1_score"])
    val_total_loss.append(loss_val)
# Out:
# BasicCNN2(
#   (layer1): Sequential(
#     (0): Conv1d(1, 64, kernel_size=(3,), stride=(1,))
#     (1): ReLU()
#     (2): Dropout(p=0.3, inplace=False)
#     (3): MaxPool1d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (layer2): Flatten(start_dim=1, end_dim=-1)
#   (layer3): Linear(in_features=320, out_features=6, bias=True)
# )
# c:\Users\User\Desktop\Hyperflow\python4FCM_Examples\.venv\lib\site-packages\sklearn\metrics\_classification.py:1471: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
# Epoch 0 - Loss: 1.9580100774765015
# {'Accuracy': 0.5245174439515645, 'F1 Score': 0.4737856627269215, 'Precision': 0.5269341987224982, 'Recall': 0.5245174439515645}
# [inference.py]: Running inference...
# Epoch 1 - Loss: 1.8422908782958984
# {'Accuracy': 0.5510580266155137, 'F1 Score': 0.5346615360356409, 'Precision': 0.5610616930667924, 'Recall': 0.5510580266155137}
# [inference.py]: Running inference...
# Epoch 2 - Loss: 1.7630314826965332
# {'Accuracy': 0.5434150581465053, 'F1 Score': 0.5674857128330307, 'Precision': 0.6019830375505886, 'Recall': 0.5434150581465053}
# [inference.py]: Running inference...
# Epoch 3 - Loss: 1.7087273597717285
# {'Accuracy': 0.45932741877472727, 'F1 Score': 0.5228358457422763, 'Precision': 0.6385104143919509, 'Recall': 0.45932741877472727}
# [inference.py]: Running inference...
# Epoch 4 - Loss: 1.667497992515564
# {'Accuracy': 0.3677167006354154, 'F1 Score': 0.42625689163497194, 'Precision': 0.666726340421474, 'Recall': 0.3677167006354154}
# [inference.py]: Running inference...
# Epoch 5 - Loss: 1.6371738910675049
# {'Accuracy': 0.3323492387003956, 'F1 Score': 0.3597344811875209, 'Precision': 0.7040528984974875, 'Recall': 0.3323492387003956}
# [inference.py]: Running inference...
# Epoch 6 - Loss: 1.6179096698760986
# {'Accuracy': 0.3345522119649922, 'F1 Score': 0.34363690767025706, 'Precision': 0.7242394685967635, 'Recall': 0.3345522119649922}
# [inference.py]: Running inference...
# Epoch 7 - Loss: 1.5964149236679077
# {'Accuracy': 0.35754106222275506, 'F1 Score': 0.35294157723853237, 'Precision': 0.7422772727783091, 'Recall': 0.35754106222275506}
# [inference.py]: Running inference...
# Epoch 8 - Loss: 1.5744655132293701
# {'Accuracy': 0.3811143747752068, 'F1 Score': 0.36759383539975493, 'Precision': 0.789273712961381, 'Recall': 0.3811143747752068}
# [inference.py]: Running inference...
# Epoch 9 - Loss: 1.550209879875183
# {'Accuracy': 0.6991817527874356, 'F1 Score': 0.7345362908816536, 'Precision': 0.8624202190064987, 'Recall': 0.6991817527874356}
# [inference.py]: Running inference...
# Epoch 24 - Loss: 1.199499249458313
# {'Accuracy': 0.6985523318546937, 'F1 Score': 0.7341947723431829, 'Precision': 0.8653514647504015, 'Recall': 0.6985523318546937}
# [inference.py]: Running inference...
# Epoch 25 - Loss: 1.1864851713180542
# {'Accuracy': 0.6858889821364345, 'F1 Score': 0.7224640380697004, 'Precision': 0.8676158934989598, 'Recall': 0.6858889821364345}
# [inference.py]: Running inference...
# Epoch 26 - Loss: 1.1633179187774658
# {'Accuracy': 0.6805389042081286, 'F1 Score': 0.7172332403124305, 'Precision': 0.871363630319272, 'Recall': 0.6805389042081286}
# [inference.py]: Running inference...
# Epoch 27 - Loss: 1.1453310251235962
# {'Accuracy': 0.6663319745833833, 'F1 Score': 0.702068735089733, 'Precision': 0.873928684359177, 'Recall': 0.6663319745833833}
# [inference.py]: Running inference...
# Epoch 28 - Loss: 1.1304264068603516
# {'Accuracy': 0.6502367821604125, 'F1 Score': 0.6840578153655547, 'Precision': 0.8781212466389491, 'Recall': 0.6502367821604125}
# [inference.py]: Running inference...
# Epoch 29 - Loss: 1.1173179149627686
# {'Accuracy': 0.6378431842704712, 'F1 Score': 0.6704125383461473, 'Precision': 0.8811791407195019, 'Recall': 0.6378431842704712}
# [inference.py]: Running inference...
# Epoch 30 - Loss: 1.1031407117843628
# {'Accuracy': 0.6286866083203453, 'F1 Score': 0.6599919540469665, 'Precision': 0.8839891992004043, 'Recall': 0.6286866083203453}
# [inference.py]: Running inference...
# Epoch 31 - Loss: 1.0907831192016602
# {'Accuracy': 0.6216580745713943, 'F1 Score': 0.6509573420467446, 'Precision': 0.8864745888513275, 'Recall': 0.6216580745713943}
# [inference.py]: Running inference...
# Epoch 32 - Loss: 1.0789545774459839
# {'Accuracy': 0.6197398393478, 'F1 Score': 0.6492018197905912, 'Precision': 0.888889423050372, 'Recall': 0.6197398393478}
# [inference.py]: Running inference...
# Epoch 33 - Loss: 1.0639641284942627
# {'Accuracy': 0.619919673900012, 'F1 Score': 0.6498368875732945, 'Precision': 0.8900057169553034, 'Recall': 0.619919673900012}
# [inference.py]: Running inference...
# Epoch 34 - Loss: 1.0500081777572632
# {'Accuracy': 0.6254495863805299, 'F1 Score': 0.656168260407031, 'Precision': 0.8915912713796004, 'Recall': 0.6254495863805299}
# [inference.py]: Running inference...
# Epoch 35 - Loss: 1.0458093881607056
# {'Accuracy': 0.6300503536746194, 'F1 Score': 0.6628049515248658, 'Precision': 0.8928291259737645, 'Recall': 0.6300503536746194}
# [inference.py]: Running inference...
# Epoch 36 - Loss: 1.030519723892212
# {'Accuracy': 0.6393567917515885, 'F1 Score': 0.673768256861186, 'Precision': 0.8938341464851314, 'Recall': 0.6393567917515885}
# [inference.py]: Running inference...
# Epoch 37 - Loss: 1.0177606344223022
# {'Accuracy': 0.6498471406306199, 'F1 Score': 0.6861373860028084, 'Precision': 0.8952772474577738, 'Recall': 0.6498471406306199}
# [inference.py]: Running inference...
# Epoch 95 - Loss: 0.6991755366325378
# {'Accuracy': 0.7846481237261719, 'F1 Score': 0.8262453883127818, 'Precision': 0.9219408245472441, 'Recall': 0.7846481237261719}
# [inference.py]: Running inference...
# Epoch 96 - Loss: 0.6934888362884521
# {'Accuracy': 0.7855323102745474, 'F1 Score': 0.8269144072869278, 'Precision': 0.9226056501651184, 'Recall': 0.7855323102745474}
# [inference.py]: Running inference...
# Epoch 97 - Loss: 0.6924228072166443
# {'Accuracy': 0.78782520081525, 'F1 Score': 0.8289696232907319, 'Precision': 0.9232147344673717, 'Recall': 0.78782520081525}
# [inference.py]: Running inference...
# Epoch 98 - Loss: 0.6851476430892944
# {'Accuracy': 0.7887693322143627, 'F1 Score': 0.8298152720641041, 'Precision': 0.9234082878132779, 'Recall': 0.7887693322143627}
# [inference.py]: Running inference...
# Epoch 99 - Loss: 0.6818956732749939
# {'Accuracy': 0.7900431602925309, 'F1 Score': 0.8307642547321006, 'Precision': 0.9235018994519687, 'Recall': 0.7900431602925309}
# [inference.py]: Running inference...
# Epoch 100 - Loss: 0.6844756603240967
# {'Accuracy': 0.7916316988370699, 'F1 Score': 0.8322550668613871, 'Precision': 0.9232575154582662, 'Recall': 0.7916316988370699}
# [inference.py]: Running inference...
# Epoch 101 - Loss: 0.6820292472839355
# {'Accuracy': 0.7915118091355953, 'F1 Score': 0.832135913929479, 'Precision': 0.9241110517262211, 'Recall': 0.7915118091355953}
# [inference.py]: Running inference...
# Epoch 102 - Loss: 0.6797128915786743
# {'Accuracy': 0.7907924709267474, 'F1 Score': 0.8315345096582444, 'Precision': 0.9239708334222314, 'Recall': 0.7907924709267474}
# [inference.py]: Running inference...
# Epoch 103 - Loss: 0.6782344579696655
# {'Accuracy': 0.7930404028293969, 'F1 Score': 0.8332728077569448, 'Precision': 0.9241086696823039, 'Recall': 0.7930404028293969}
# [inference.py]: Running inference...
# Epoch 104 - Loss: 0.6687487959861755
# {'Accuracy': 0.7913769332214363, 'F1 Score': 0.8318326273292919, 'Precision': 0.9243120507237509, 'Recall': 0.7913769332214363}
# [inference.py]: Running inference...
# Epoch 105 - Loss: 0.6712602376937866
# {'Accuracy': 0.7912420573072773, 'F1 Score': 0.8320071692932146, 'Precision': 0.9236116512877581, 'Recall': 0.7912420573072773}
# [inference.py]: Running inference...
# Epoch 106 - Loss: 0.6668664216995239
# {'Accuracy': 0.7939695480158254, 'F1 Score': 0.8343560176686946, 'Precision': 0.9253513223441574, 'Recall': 0.7939695480158254}
# [inference.py]: Running inference...
# Epoch 107 - Loss: 0.6661722660064697
# {'Accuracy': 0.7915267953482796, 'F1 Score': 0.8323965109441309, 'Precision': 0.9243199052968419, 'Recall': 0.7915267953482796}
# [inference.py]: Running inference...
# Epoch 108 - Loss: 0.6639630794525146
# {'Accuracy': 0.7925308715981297, 'F1 Score': 0.8331463999161633, 'Precision': 0.9243255054911272, 'Recall': 0.7925308715981297}
# Epoch 123 - Loss: 0.6334269642829895
# {'Accuracy': 0.8016275026975183, 'F1 Score': 0.8410884232460724, 'Precision': 0.9272227860382574, 'Recall': 0.8016275026975183}
# [inference.py]: Running inference...
# Epoch 124 - Loss: 0.6327251195907593
# {'Accuracy': 0.7999490468768733, 'F1 Score': 0.8394176554561683, 'Precision': 0.9268546192857624, 'Recall': 0.7999490468768733}
# [inference.py]: Running inference...
# Epoch 125 - Loss: 0.6339308023452759
# {'Accuracy': 0.8016275026975183, 'F1 Score': 0.8405802609387037, 'Precision': 0.92649983664079, 'Recall': 0.8016275026975183}
# [inference.py]: Running inference...
# Epoch 126 - Loss: 0.6274468302726746
# {'Accuracy': 0.8026315789473685, 'F1 Score': 0.8417853790019072, 'Precision': 0.9277773437995958, 'Recall': 0.8026315789473685}
# [inference.py]: Running inference...
# Epoch 127 - Loss: 0.6315072178840637
# {'Accuracy': 0.8028114134995804, 'F1 Score': 0.8418853307450427, 'Precision': 0.9269575180608001, 'Recall': 0.8028114134995804}
# [inference.py]: Running inference...
# Epoch 128 - Loss: 0.6268203854560852
# {'Accuracy': 0.8028563721376334, 'F1 Score': 0.8419000688965483, 'Precision': 0.9272212346756514, 'Recall': 0.8028563721376334}
# [inference.py]: Running inference...
# Epoch 129 - Loss: 0.6222048401832581
# {'Accuracy': 0.8038304759621149, 'F1 Score': 0.8428315604842452, 'Precision': 0.9273420239745515, 'Recall': 0.8038304759621149}
# [inference.py]: Running inference...
# Epoch 130 - Loss: 0.6227641701698303
# {'Accuracy': 0.8028563721376334, 'F1 Score': 0.841769662275562, 'Precision': 0.9276334165998048, 'Recall': 0.8028563721376334}
# [inference.py]: Running inference...
# Epoch 131 - Loss: 0.6196934580802917
# {'Accuracy': 0.8043699796187508, 'F1 Score': 0.8430930186663869, 'Precision': 0.9282655866848407, 'Recall': 0.8043699796187508}
# [inference.py]: Running inference...
# Epoch 132 - Loss: 0.622222363948822
# {'Accuracy': 0.8037105862606402, 'F1 Score': 0.8426836017340478, 'Precision': 0.927803032146269, 'Recall': 0.8037105862606402}
# [inference.py]: Running inference...
# Epoch 133 - Loss: 0.6160066723823547
# {'Accuracy': 0.8039803380889582, 'F1 Score': 0.8430803060289717, 'Precision': 0.9284232070929157, 'Recall': 0.8039803380889582}
# [inference.py]: Running inference...
# Epoch 134 - Loss: 0.6154268383979797
# {'Accuracy': 0.8045048555329097, 'F1 Score': 0.8433240612471246, 'Precision': 0.9281322668912314, 'Recall': 0.8045048555329097}
# [inference.py]: Running inference...
# Epoch 135 - Loss: 0.6144766211509705
# {'Accuracy': 0.8044598968948568, 'F1 Score': 0.8434246232748249, 'Precision': 0.9282108594800759, 'Recall': 0.8044598968948568}
# [inference.py]: Running inference...
# Epoch 136 - Loss: 0.6098960041999817
# {'Accuracy': 0.8055089317827598, 'F1 Score': 0.8439912755021794, 'Precision': 0.9277861919167346, 'Recall': 0.8055089317827598}
# [inference.py]: Running inference...
# Epoch 137 - Loss: 0.610684335231781
# {'Accuracy': 0.8063931183311354, 'F1 Score': 0.8447539798957983, 'Precision': 0.9275525534652036, 'Recall': 0.8063931183311354}
# [inference.py]: Running inference...
# Epoch 138 - Loss: 0.6117924451828003
# {'Accuracy': 0.806692842584822, 'F1 Score': 0.8449983135895828, 'Precision': 0.9278123590997843, 'Recall': 0.806692842584822}
# [inference.py]: Running inference...
# Epoch 139 - Loss: 0.6111592650413513
# {'Accuracy': 0.8086560364464692, 'F1 Score': 0.8464094675653595, 'Precision': 0.9283536759286501, 'Recall': 0.8086560364464692}
# [inference.py]: Running inference...
# Epoch 140 - Loss: 0.6070094704627991
# {'Accuracy': 0.8079516844503057, 'F1 Score': 0.8459071547978553, 'Precision': 0.9280909404534666, 'Recall': 0.8079516844503057}
# [inference.py]: Running inference...
# Epoch 141 - Loss: 0.6016319394111633
# {'Accuracy': 0.807921712024937, 'F1 Score': 0.8460679064761402, 'Precision': 0.9293037257004042, 'Recall': 0.807921712024937}
# [inference.py]: Running inference...
# Epoch 142 - Loss: 0.5999962091445923
# {'Accuracy': 0.8090906366143148, 'F1 Score': 0.8468053004611578, 'Precision': 0.9287338052610161, 'Recall': 0.8090906366143148}
# [inference.py]: Running inference...
# Epoch 143 - Loss: 0.5998086929321289
# {'Accuracy': 0.808641050233785, 'F1 Score': 0.8466247527567203, 'Precision': 0.9293775569055308, 'Recall': 0.808641050233785}
# [inference.py]: Running inference...
# Epoch 144 - Loss: 0.5991610288619995
# {'Accuracy': 0.8098099748231626, 'F1 Score': 0.8477794823181759, 'Precision': 0.929162788170409, 'Recall': 0.8098099748231626}
# [inference.py]: Running inference...
# Epoch 145 - Loss: 0.5987654328346252
# {'Accuracy': 0.8099898093753747, 'F1 Score': 0.8475914250204741, 'Precision': 0.9287961575567074, 'Recall': 0.8099898093753747}
# [inference.py]: Running inference...
# Epoch 146 - Loss: 0.6000869870185852
# {'Accuracy': 0.809824961035847, 'F1 Score': 0.8476194445105587, 'Precision': 0.9284669546611467, 'Recall': 0.809824961035847}
# [inference.py]: Running inference...
# Epoch 147 - Loss: 0.5996810793876648
# {'Accuracy': 0.8105742716700636, 'F1 Score': 0.8482542609019273, 'Precision': 0.9289483140329223, 'Recall': 0.8105742716700636}
# [inference.py]: Running inference...
# Epoch 148 - Loss: 0.5948790907859802
# {'Accuracy': 0.8112036926028054, 'F1 Score': 0.8487996669927462, 'Precision': 0.9296585438290549, 'Recall': 0.8112036926028054}
# [inference.py]: Running inference...
# Epoch 149 - Loss: 0.5978036522865295
# {'Accuracy': 0.8113385685169644, 'F1 Score': 0.8490080973760548, 'Precision': 0.9296091571837292, 'Recall': 0.8113385685169644}
# [inference.py]: Running inference...
# Epoch 150 - Loss: 0.5923017263412476
# {'Accuracy': 0.8109788994125404, 'F1 Score': 0.8485778711269703, 'Precision': 0.9295165732270356, 'Recall': 0.8109788994125404}
# [inference.py]: Running inference...
# Epoch 151 - Loss: 0.5894790887832642
# {'Accuracy': 0.81177316868481, 'F1 Score': 0.8489702573475254, 'Precision': 0.9289247151732074, 'Recall': 0.81177316868481}
# [inference.py]: Running inference...
# Epoch 166 - Loss: 0.5772414803504944
# {'Accuracy': 0.8189815369859729, 'F1 Score': 0.8546917258551698, 'Precision': 0.9303223413765284, 'Recall': 0.8189815369859729}
# [inference.py]: Running inference...
# Epoch 167 - Loss: 0.5772289633750916
# {'Accuracy': 0.8178575710346482, 'F1 Score': 0.854031907534145, 'Precision': 0.9302605602938652, 'Recall': 0.8178575710346482}
# [inference.py]: Running inference...
# Epoch 168 - Loss: 0.5728586316108704
# {'Accuracy': 0.8186518403069176, 'F1 Score': 0.8544601496884677, 'Precision': 0.9310760368498393, 'Recall': 0.8186518403069176}
# [inference.py]: Running inference...
# Epoch 169 - Loss: 0.5718211531639099
# {'Accuracy': 0.816808536146745, 'F1 Score': 0.853054698817699, 'Precision': 0.930052943017087, 'Recall': 0.816808536146745}
# [inference.py]: Running inference...
# Epoch 170 - Loss: 0.574690043926239
# {'Accuracy': 0.8187417575830236, 'F1 Score': 0.8548903893993692, 'Precision': 0.9312131379518778, 'Recall': 0.8187417575830236}
# [inference.py]: Running inference...
# Epoch 171 - Loss: 0.567015528678894
# {'Accuracy': 0.8180673780122287, 'F1 Score': 0.854546370558651, 'Precision': 0.9320948076122079, 'Recall': 0.8180673780122287}
# [inference.py]: Running inference...
# Epoch 172 - Loss: 0.5642384886741638
# {'Accuracy': 0.8188616472844983, 'F1 Score': 0.8550854250923151, 'Precision': 0.931820942707448, 'Recall': 0.8188616472844983}
# [inference.py]: Running inference...
# Epoch 173 - Loss: 0.5635596513748169
# {'Accuracy': 0.8190414818367102, 'F1 Score': 0.8550892970320217, 'Precision': 0.9311596929994344, 'Recall': 0.8190414818367102}
# [inference.py]: Running inference...
# Epoch 174 - Loss: 0.5625675320625305
# {'Accuracy': 0.8198807097470328, 'F1 Score': 0.8554791897942168, 'Precision': 0.9309805889275989, 'Recall': 0.8198807097470328}
# [inference.py]: Running inference...
# Epoch 175 - Loss: 0.5646323561668396
# {'Accuracy': 0.819895695959717, 'F1 Score': 0.8556577259768282, 'Precision': 0.9308804985230127, 'Recall': 0.819895695959717}
# [inference.py]: Running inference...
# Epoch 176 - Loss: 0.5641744136810303
# {'Accuracy': 0.8224283659033689, 'F1 Score': 0.857379221502938, 'Precision': 0.9311512760344625, 'Recall': 0.8224283659033689}
# [inference.py]: Running inference...
# Epoch 177 - Loss: 0.5652766823768616
# {'Accuracy': 0.8226831315190025, 'F1 Score': 0.857250927780085, 'Precision': 0.9302760955950675, 'Recall': 0.8226831315190025}
# [inference.py]: Running inference...
# Epoch 178 - Loss: 0.5654051899909973
# {'Accuracy': 0.822113655436998, 'F1 Score': 0.8572545627430991, 'Precision': 0.9311011514705501, 'Recall': 0.822113655436998}
# [inference.py]: Running inference...
# Epoch 179 - Loss: 0.5606147646903992
# {'Accuracy': 0.8228779522838988, 'F1 Score': 0.8580903177176624, 'Precision': 0.9318969854948329, 'Recall': 0.8228779522838988}
# [inference.py]: Running inference...
# Epoch 180 - Loss: 0.5558319091796875
# {'Accuracy': 0.8189815369859729, 'F1 Score': 0.8549660637241954, 'Precision': 0.9319220278282981, 'Recall': 0.8189815369859729}
# [inference.py]: Running inference...
# Epoch 181 - Loss: 0.5547425746917725
# {'Accuracy': 0.821798944970627, 'F1 Score': 0.8573255541359056, 'Precision': 0.9323070733811025, 'Recall': 0.821798944970627}
# [inference.py]: Running inference...
# Epoch 182 - Loss: 0.5563297867774963
# {'Accuracy': 0.8216191104184151, 'F1 Score': 0.8572338672755427, 'Precision': 0.9320396720604093, 'Recall': 0.8216191104184151}
# [inference.py]: Running inference...
# Epoch 183 - Loss: 0.5597235560417175
# {'Accuracy': 0.8228030212204772, 'F1 Score': 0.857883079099433, 'Precision': 0.9318313440145286, 'Recall': 0.8228030212204772}
# [inference.py]: Running inference...
# Epoch 184 - Loss: 0.5554884076118469
# {'Accuracy': 0.825155856611917, 'F1 Score': 0.8595435985881958, 'Precision': 0.9312711163117138, 'Recall': 0.825155856611917}
# [inference.py]: Running inference...
# Epoch 185 - Loss: 0.5503180027008057
# {'Accuracy': 0.8261599328617671, 'F1 Score': 0.8600957377134485, 'Precision': 0.9316571256958899, 'Recall': 0.8261599328617671}
# [inference.py]: Running inference...
# Epoch 186 - Loss: 0.558393120765686
# {'Accuracy': 0.8245264356791752, 'F1 Score': 0.8588256876515127, 'Precision': 0.9306396059205438, 'Recall': 0.8245264356791752}
# [inference.py]: Running inference...
# Epoch 187 - Loss: 0.5523408651351929
# {'Accuracy': 0.8254256084402349, 'F1 Score': 0.8598901703761127, 'Precision': 0.9322259243430215, 'Recall': 0.8254256084402349}
# [inference.py]: Running inference...
# Epoch 188 - Loss: 0.5528672337532043
# {'Accuracy': 0.8231477041122167, 'F1 Score': 0.8581705492440873, 'Precision': 0.9315726956813898, 'Recall': 0.8231477041122167}
# [inference.py]: Running inference...
# Epoch 189 - Loss: 0.5498440861701965
# {'Accuracy': 0.8244964632538065, 'F1 Score': 0.8593296398648436, 'Precision': 0.9326943684858169, 'Recall': 0.8244964632538065}
# [inference.py]: Running inference...
# Epoch 190 - Loss: 0.5480117201805115
# {'Accuracy': 0.8230278144107421, 'F1 Score': 0.8583571683654397, 'Precision': 0.9328404035539649, 'Recall': 0.8230278144107421}
# [inference.py]: Running inference...
# Epoch 191 - Loss: 0.5565205216407776
# {'Accuracy': 0.825155856611917, 'F1 Score': 0.8601005244896457, 'Precision': 0.932406052603974, 'Recall': 0.825155856611917}
# [inference.py]: Running inference...
# Epoch 192 - Loss: 0.5484117269515991
# {'Accuracy': 0.8244515046157536, 'F1 Score': 0.8590760954720994, 'Precision': 0.931944277432035, 'Recall': 0.8244515046157536}
# [inference.py]: Running inference...
# Epoch 193 - Loss: 0.5504891276359558
# {'Accuracy': 0.8254106222275507, 'F1 Score': 0.8596637508229248, 'Precision': 0.9318280122856166, 'Recall': 0.8254106222275507}
# [inference.py]: Running inference...
# Epoch 194 - Loss: 0.5495033264160156
# {'Accuracy': 0.8262498501378731, 'F1 Score': 0.8604867606060471, 'Precision': 0.9318874313971355, 'Recall': 0.8262498501378731}
# [inference.py]: Running inference...
# Epoch 195 - Loss: 0.5441131591796875
# {'Accuracy': 0.8258901810334492, 'F1 Score': 0.8602214377989875, 'Precision': 0.9324532229400163, 'Recall': 0.8258901810334492}
# [inference.py]: Running inference...
# Epoch 196 - Loss: 0.540741503238678
# {'Accuracy': 0.8283778923390481, 'F1 Score': 0.8620088370106673, 'Precision': 0.9326872797084084, 'Recall': 0.8283778923390481}
# [inference.py]: Running inference...
# Epoch 197 - Loss: 0.547391951084137
# {'Accuracy': 0.8288574511449467, 'F1 Score': 0.8622353620868377, 'Precision': 0.9321512213893897, 'Recall': 0.8288574511449467}
# [inference.py]: Running inference...
# Epoch 198 - Loss: 0.5427392721176147
# {'Accuracy': 0.8281680853614675, 'F1 Score': 0.8619990157569821, 'Precision': 0.9325480670737575, 'Recall': 0.8281680853614675}
# [inference.py]: Running inference...
# Epoch 199 - Loss: 0.5416064858436584
# {'Accuracy': 0.8281381129360987, 'F1 Score': 0.8619256242408935, 'Precision': 0.9325370255809116, 'Recall': 0.8281381129360987}
# [inference.py]: Running inference...
# Epoch 200 - Loss: 0.540756106376648
# {'Accuracy': 0.8287225752307876, 'F1 Score': 0.8623687458573588, 'Precision': 0.9323594029441066, 'Recall': 0.8287225752307876}
# [inference.py]: Running inference...
# Epoch 201 - Loss: 0.5399497747421265
# {'Accuracy': 0.8276735403428845, 'F1 Score': 0.8616280335164386, 'Precision': 0.9328396176488728, 'Recall': 0.8276735403428845}
# [inference.py]: Running inference...
# Epoch 202 - Loss: 0.5385788679122925
# {'Accuracy': 0.8264896295408224, 'F1 Score': 0.8607329380902382, 'Precision': 0.9320524960814327, 'Recall': 0.8264896295408224}
# [inference.py]: Running inference...
# Epoch 203 - Loss: 0.5377492308616638
# {'Accuracy': 0.828737561443472, 'F1 Score': 0.8624905267503843, 'Precision': 0.9330271663218008, 'Recall': 0.828737561443472}
# [inference.py]: Running inference...
# Epoch 204 - Loss: 0.5393958687782288
# {'Accuracy': 0.8274787195779882, 'F1 Score': 0.8615752353567686, 'Precision': 0.9330425081918848, 'Recall': 0.8274787195779882}
# [inference.py]: Running inference...
# Epoch 205 - Loss: 0.5380520820617676
# {'Accuracy': 0.8291122167605802, 'F1 Score': 0.862570186776952, 'Precision': 0.9326399529192717, 'Recall': 0.8291122167605802}
# [inference.py]: Running inference...
# Epoch 206 - Loss: 0.538580596446991
# {'Accuracy': 0.8284078647644167, 'F1 Score': 0.8620597199586003, 'Precision': 0.9323132399687066, 'Recall': 0.8284078647644167}
# [inference.py]: Running inference...
# Epoch 207 - Loss: 0.5328065752983093
# {'Accuracy': 0.8286626303800504, 'F1 Score': 0.8624526390018438, 'Precision': 0.9330819216081008, 'Recall': 0.8286626303800504}
# [inference.py]: Running inference...
# Epoch 208 - Loss: 0.5349166393280029
# {'Accuracy': 0.8296816928425849, 'F1 Score': 0.8630564349629447, 'Precision': 0.9331019120133291, 'Recall': 0.8296816928425849}
# [inference.py]: Running inference...
# Epoch 209 - Loss: 0.5368185639381409
# {'Accuracy': 0.8288124925068937, 'F1 Score': 0.8624874035910806, 'Precision': 0.9329064889198438, 'Recall': 0.8288124925068937}
# [inference.py]: Running inference...
# Epoch 210 - Loss: 0.5359960794448853
# {'Accuracy': 0.8294868720776886, 'F1 Score': 0.8633398109165106, 'Precision': 0.9330206768094385, 'Recall': 0.8294868720776886}
# [inference.py]: Running inference...
# Epoch 211 - Loss: 0.532646119594574
# {'Accuracy': 0.8307457139431723, 'F1 Score': 0.8641148454764401, 'Precision': 0.9332419658779398, 'Recall': 0.8307457139431723}
# [inference.py]: Running inference...
# Epoch 212 - Loss: 0.5339085459709167
# {'Accuracy': 0.8308506174319626, 'F1 Score': 0.8641226676933962, 'Precision': 0.9328538893734167, 'Recall': 0.8308506174319626}
# [inference.py]: Running inference...
# Epoch 213 - Loss: 0.5319445133209229
# {'Accuracy': 0.8322443352116053, 'F1 Score': 0.8651184778699736, 'Precision': 0.9334825678046408, 'Recall': 0.8322443352116053}
# [inference.py]: Running inference...
# Epoch 214 - Loss: 0.5356568098068237
# {'Accuracy': 0.8326339767413979, 'F1 Score': 0.86515550236202, 'Precision': 0.9323642162645017, 'Recall': 0.8326339767413979}
# [inference.py]: Running inference...
# Epoch 215 - Loss: 0.5305180549621582
# {'Accuracy': 0.8330386044838748, 'F1 Score': 0.8657190932102703, 'Precision': 0.9338414480556534, 'Recall': 0.8330386044838748}
# [inference.py]: Running inference...
# Epoch 216 - Loss: 0.5297172665596008
# {'Accuracy': 0.8334132598009831, 'F1 Score': 0.8657892595327694, 'Precision': 0.9332858700610966, 'Recall': 0.8334132598009831}
# [inference.py]: Running inference...
# Epoch 217 - Loss: 0.5339211821556091
# {'Accuracy': 0.8298914998201654, 'F1 Score': 0.8631478244147396, 'Precision': 0.9328227288484741, 'Recall': 0.8298914998201654}
# [inference.py]: Running inference...
# Epoch 218 - Loss: 0.5240404009819031
# {'Accuracy': 0.8316448867042321, 'F1 Score': 0.8647576919572533, 'Precision': 0.9343489842080007, 'Recall': 0.8316448867042321}
# [inference.py]: Running inference...
# Epoch 219 - Loss: 0.5223890542984009
# {'Accuracy': 0.8327238940175039, 'F1 Score': 0.8655534535211193, 'Precision': 0.9341996621086633, 'Recall': 0.8327238940175039}
# [inference.py]: Running inference...
# Epoch 220 - Loss: 0.5272889137268066
# {'Accuracy': 0.8327688526555569, 'F1 Score': 0.8656660257611059, 'Precision': 0.9335937970515752, 'Recall': 0.8327688526555569}
# [inference.py]: Running inference...
# Epoch 221 - Loss: 0.5296373963356018
# {'Accuracy': 0.8339827358829877, 'F1 Score': 0.8665802600759935, 'Precision': 0.933661902106526, 'Recall': 0.8339827358829877}
# [inference.py]: Running inference...
# Epoch 222 - Loss: 0.5260984897613525
# {'Accuracy': 0.8353015225992088, 'F1 Score': 0.867322223172831, 'Precision': 0.9336360698195725, 'Recall': 0.8353015225992088}
# [inference.py]: Running inference...
# Epoch 223 - Loss: 0.5240436792373657
# {'Accuracy': 0.8346421292410982, 'F1 Score': 0.8671560362042284, 'Precision': 0.9339459051633635, 'Recall': 0.8346421292410982}
# [inference.py]: Running inference...
# Epoch 224 - Loss: 0.5206652879714966
# {'Accuracy': 0.8336979978419854, 'F1 Score': 0.8663304410117548, 'Precision': 0.9336770856870013, 'Recall': 0.8336979978419854}
# [inference.py]: Running inference...
# Epoch 225 - Loss: 0.5216112732887268
# {'Accuracy': 0.8343274187747273, 'F1 Score': 0.8666686192992693, 'Precision': 0.9341148312318776, 'Recall': 0.8343274187747273}
# [inference.py]: Running inference...
# Epoch 226 - Loss: 0.5258511900901794
# {'Accuracy': 0.8336979978419854, 'F1 Score': 0.866162192186772, 'Precision': 0.9335775108050232, 'Recall': 0.8336979978419854}
# [inference.py]: Running inference...
# Epoch 227 - Loss: 0.526257336139679
# {'Accuracy': 0.8336979978419854, 'F1 Score': 0.866284171770572, 'Precision': 0.9334442734883931, 'Recall': 0.8336979978419854}
# [inference.py]: Running inference...
# Epoch 228 - Loss: 0.5189208388328552
# {'Accuracy': 0.833772928905407, 'F1 Score': 0.8663352598548378, 'Precision': 0.9344495315662572, 'Recall': 0.833772928905407}
# [inference.py]: Running inference...
# Epoch 229 - Loss: 0.5190137624740601
# {'Accuracy': 0.8335181632897735, 'F1 Score': 0.8661691339192609, 'Precision': 0.9339797359535258, 'Recall': 0.8335181632897735}
# [inference.py]: Running inference...
# Epoch 230 - Loss: 0.5227567553520203
# {'Accuracy': 0.8332184390360868, 'F1 Score': 0.8659923244227781, 'Precision': 0.9342037817118372, 'Recall': 0.8332184390360868}
# [inference.py]: Running inference...
# Epoch 231 - Loss: 0.5165736079216003
# {'Accuracy': 0.8356462054909484, 'F1 Score': 0.8677739669051229, 'Precision': 0.9344685601185457, 'Recall': 0.8356462054909484}
# [inference.py]: Running inference...
# Epoch 232 - Loss: 0.5169020295143127
# {'Accuracy': 0.8377742476921233, 'F1 Score': 0.869231740323508, 'Precision': 0.934205238977354, 'Recall': 0.8377742476921233}
# [inference.py]: Running inference...
# Epoch 233 - Loss: 0.5175403952598572
# {'Accuracy': 0.8367701714422731, 'F1 Score': 0.8686172000290611, 'Precision': 0.9342087096414353, 'Recall': 0.8367701714422731}
# [inference.py]: Running inference...
# Epoch 234 - Loss: 0.519236147403717
# {'Accuracy': 0.8379390960316508, 'F1 Score': 0.8692580757531998, 'Precision': 0.9338932208127028, 'Recall': 0.8379390960316508}
# [inference.py]: Running inference...
# Epoch 235 - Loss: 0.5157890319824219
# ...
# [inference.py]: Running inference...
# Epoch 321 - Loss: 0.47334834933280945
# {'Accuracy': 0.8510820045558086, 'F1 Score': 0.8798529841330449, 'Precision': 0.937766492163247, 'Recall': 0.8510820045558086}
# [inference.py]: Running inference...
# Epoch 322 - Loss: 0.4736658036708832
# {'Accuracy': 0.8500329696679055, 'F1 Score': 0.8789255877320762, 'Precision': 0.9374340341829513, 'Recall': 0.8500329696679055}
# [inference.py]: Running inference...
# Epoch 323 - Loss: 0.4727601706981659
# {'Accuracy': 0.8509021700035967, 'F1 Score': 0.8796881141737417, 'Precision': 0.9384927420768927, 'Recall': 0.8509021700035967}
# [inference.py]: Running inference...
# Epoch 324 - Loss: 0.47300589084625244
# {'Accuracy': 0.8470806857690925, 'F1 Score': 0.8767797299222798, 'Precision': 0.9375184513078356, 'Recall': 0.8470806857690925}
# [inference.py]: Running inference...
# Epoch 325 - Loss: 0.474962443113327
# {'Accuracy': 0.8471256444071454, 'F1 Score': 0.8768595062063549, 'Precision': 0.9377419159099635, 'Recall': 0.8471256444071454}
# [inference.py]: Running inference...
# Epoch 326 - Loss: 0.4725165367126465
# {'Accuracy': 0.8461365543699796, 'F1 Score': 0.8762524896852489, 'Precision': 0.937788434104618, 'Recall': 0.8461365543699796}
# [inference.py]: Running inference...
# Epoch 327 - Loss: 0.47469863295555115
# {'Accuracy': 0.8487891140151061, 'F1 Score': 0.8781411675650483, 'Precision': 0.9375476641671096, 'Recall': 0.8487891140151061}
# [inference.py]: Running inference...
# Epoch 328 - Loss: 0.46884965896606445
# {'Accuracy': 0.8486842105263158, 'F1 Score': 0.8782335957638826, 'Precision': 0.9378417916098598, 'Recall': 0.8486842105263158}
# [inference.py]: Running inference...
# Epoch 329 - Loss: 0.46966370940208435
# {'Accuracy': 0.8505724733245414, 'F1 Score': 0.8794671370574839, 'Precision': 0.9378590736897342, 'Recall': 0.8505724733245414}
# [inference.py]: Running inference...
# Epoch 330 - Loss: 0.46194449067115784
# {'Accuracy': 0.8513667425968109, 'F1 Score': 0.8802072709994475, 'Precision': 0.9391884936027057, 'Recall': 0.8513667425968109}
# [inference.py]: Running inference...
# Epoch 331 - Loss: 0.46909841895103455
# {'Accuracy': 0.8536596331375135, 'F1 Score': 0.8815038001505856, 'Precision': 0.9382917015267629, 'Recall': 0.8536596331375135}
# [inference.py]: Running inference...
# Epoch 332 - Loss: 0.4644117057323456
# {'Accuracy': 0.854588778323942, 'F1 Score': 0.8823692184448729, 'Precision': 0.938788533033698, 'Recall': 0.854588778323942}
# [inference.py]: Running inference...
# Epoch 333 - Loss: 0.4628336429595947
# {'Accuracy': 0.8531051432681933, 'F1 Score': 0.8817284125695797, 'Precision': 0.9392094173558928, 'Recall': 0.8531051432681933}
# [inference.py]: Running inference...
# Epoch 334 - Loss: 0.46525776386260986
# {'Accuracy': 0.8543489989209927, 'F1 Score': 0.8826291758336384, 'Precision': 0.9396373549675647, 'Recall': 0.8543489989209927}
# [inference.py]: Running inference...
# Epoch 335 - Loss: 0.4657309949398041
# {'Accuracy': 0.8536296607121449, 'F1 Score': 0.8818267535306621, 'Precision': 0.9384553543028054, 'Recall': 0.8536296607121449}
# [inference.py]: Running inference...
# Epoch 336 - Loss: 0.469327837228775
# {'Accuracy': 0.8528503776525597, 'F1 Score': 0.8810514130373411, 'Precision': 0.938323175195477, 'Recall': 0.8528503776525597}
# [inference.py]: Running inference...
# Epoch 337 - Loss: 0.46347931027412415
# {'Accuracy': 0.852865363865244, 'F1 Score': 0.8810878120063017, 'Precision': 0.9387470902605247, 'Recall': 0.852865363865244}
# [inference.py]: Running inference...
# Epoch 338 - Loss: 0.4586121141910553
# {'Accuracy': 0.853045198417456, 'F1 Score': 0.8812099084683892, 'Precision': 0.938973195397872, 'Recall': 0.853045198417456}
# [inference.py]: Running inference...
# Epoch 339 - Loss: 0.4670366942882538
# {'Accuracy': 0.8515315909363386, 'F1 Score': 0.8799602125250044, 'Precision': 0.937355907886777, 'Recall': 0.8515315909363386}
# [inference.py]: Running inference...
# Epoch 340 - Loss: 0.45550230145454407
# {'Accuracy': 0.8528803500779283, 'F1 Score': 0.8809603602326799, 'Precision': 0.9384265502981878, 'Recall': 0.8528803500779283}
# [inference.py]: Running inference...
# Epoch 341 - Loss: 0.4636131227016449
# {'Accuracy': 0.8536446469248291, 'F1 Score': 0.8816507287201429, 'Precision': 0.9393661432298914, 'Recall': 0.8536446469248291}
# [inference.py]: Running inference...
# Epoch 342 - Loss: 0.4623280465602875
# {'Accuracy': 0.8535097710106702, 'F1 Score': 0.881427022606965, 'Precision': 0.9384162868762063, 'Recall': 0.8535097710106702}
# [inference.py]: Running inference...
# Epoch 343 - Loss: 0.4631439447402954
# {'Accuracy': 0.8523708188466611, 'F1 Score': 0.8806424029183516, 'Precision': 0.9383636858920918, 'Recall': 0.8523708188466611}
# [inference.py]: Running inference...
# Epoch 344 - Loss: 0.4621674120426178
# {'Accuracy': 0.8536746193501978, 'F1 Score': 0.8815853753008965, 'Precision': 0.9386452547520813, 'Recall': 0.8536746193501978}
# [inference.py]: Running inference...
# Epoch 345 - Loss: 0.4622405469417572
# {'Accuracy': 0.8524007912720297, 'F1 Score': 0.8807037335619406, 'Precision': 0.9379833913482526, 'Recall': 0.8524007912720297}
# [inference.py]: Running inference...
# Epoch 346 - Loss: 0.4580645263195038
# {'Accuracy': 0.854453902409783, 'F1 Score': 0.8827102797890345, 'Precision': 0.9395656118935393, 'Recall': 0.854453902409783}
# [inference.py]: Running inference...
# Epoch 347 - Loss: 0.46422669291496277
# {'Accuracy': 0.852730487951085, 'F1 Score': 0.8811878143455564, 'Precision': 0.938430980939784, 'Recall': 0.852730487951085}
# [inference.py]: Running inference...
# Epoch 348 - Loss: 0.46115371584892273
# {'Accuracy': 0.8540193022419375, 'F1 Score': 0.8822227009095057, 'Precision': 0.9386020050916652, 'Recall': 0.8540193022419375}
# [inference.py]: Running inference...
# Epoch 349 - Loss: 0.4615415334701538
# {'Accuracy': 0.8525206809735044, 'F1 Score': 0.8810154479663881, 'Precision': 0.938418142643733, 'Recall': 0.8525206809735044}
# [inference.py]: Running inference...
# Epoch 350 - Loss: 0.45876917243003845
# {'Accuracy': 0.8532999640330896, 'F1 Score': 0.8816662340248637, 'Precision': 0.9386936717022268, 'Recall': 0.8532999640330896}
# [inference.py]: Running inference...
# Epoch 351 - Loss: 0.4674851894378662
# {'Accuracy': 0.8543789713463613, 'F1 Score': 0.8820706642917687, 'Precision': 0.9384435400651708, 'Recall': 0.8543789713463613}
# [inference.py]: Running inference...
# Epoch 352 - Loss: 0.46260926127433777
# {'Accuracy': 0.8521460256563961, 'F1 Score': 0.8805401707327485, 'Precision': 0.9383710086935362, 'Recall': 0.8521460256563961}
# [inference.py]: Running inference...
# Epoch 353 - Loss: 0.4616164267063141
# {'Accuracy': 0.8526255844622946, 'F1 Score': 0.8807034452677508, 'Precision': 0.9381968875731912, 'Recall': 0.8526255844622946}
# [inference.py]: Running inference...
# Epoch 354 - Loss: 0.4586571455001831
# {'Accuracy': 0.8519811773168685, 'F1 Score': 0.8804684582580694, 'Precision': 0.9391304260957772, 'Recall': 0.8519811773168685}
# [inference.py]: Running inference...
# Epoch 355 - Loss: 0.4530268609523773
# {'Accuracy': 0.849508452223954, 'F1 Score': 0.8786744429806207, 'Precision': 0.938338936308034, 'Recall': 0.849508452223954}
# [inference.py]: Running inference...
# Epoch 356 - Loss: 0.45815491676330566
# {'Accuracy': 0.8541242057307278, 'F1 Score': 0.8820824166653939, 'Precision': 0.9390468925546349, 'Recall': 0.8541242057307278}
# [inference.py]: Running inference...
# Epoch 357 - Loss: 0.4547092914581299
# {'Accuracy': 0.8538844263277784, 'F1 Score': 0.8820136737609683, 'Precision': 0.9390875623587973, 'Recall': 0.8538844263277784}
# [inference.py]: Running inference...
# Epoch 358 - Loss: 0.4576807916164398
# {'Accuracy': 0.8550833233425249, 'F1 Score': 0.8826941730662653, 'Precision': 0.9384851729151044, 'Recall': 0.8550833233425249}
# [inference.py]: Running inference...
# Epoch 359 - Loss: 0.4612564742565155
# {'Accuracy': 0.8563871238460616, 'F1 Score': 0.883883291820484, 'Precision': 0.9390840368083135, 'Recall': 0.8563871238460616}
# [inference.py]: Running inference...
# Epoch 360 - Loss: 0.45944511890411377
# {'Accuracy': 0.8558326339767414, 'F1 Score': 0.8833467441030867, 'Precision': 0.938937006832943, 'Recall': 0.8558326339767414}
# [inference.py]: Running inference...
# Epoch 361 - Loss: 0.46069517731666565
# {'Accuracy': 0.8546936818127323, 'F1 Score': 0.8825568148028947, 'Precision': 0.9391373298452887, 'Recall': 0.8546936818127323}
# [inference.py]: Running inference...
# Epoch 362 - Loss: 0.4553212821483612
# {'Accuracy': 0.8545288334732046, 'F1 Score': 0.8824405459894863, 'Precision': 0.9391570921447212, 'Recall': 0.8545288334732046}
# [inference.py]: Running inference...
# Epoch 363 - Loss: 0.4564759433269501
# {'Accuracy': 0.8541691643687808, 'F1 Score': 0.8822760607424163, 'Precision': 0.9389890489957802, 'Recall': 0.8541691643687808}
# [inference.py]: Running inference...
# Epoch 364 - Loss: 0.45482492446899414
# {'Accuracy': 0.8515315909363386, 'F1 Score': 0.8801422216115335, 'Precision': 0.9383166709540062, 'Recall': 0.8515315909363386}
# [inference.py]: Running inference...
# Epoch 365 - Loss: 0.45610570907592773
# {'Accuracy': 0.8539143987531471, 'F1 Score': 0.8821176175565844, 'Precision': 0.9392014687862114, 'Recall': 0.8539143987531471}
# [inference.py]: Running inference...
# Epoch 366 - Loss: 0.4631437063217163
# {'Accuracy': 0.8518612876153938, 'F1 Score': 0.8807612176205961, 'Precision': 0.9392678605361087, 'Recall': 0.8518612876153938}
# [inference.py]: Running inference...
# Epoch 367 - Loss: 0.45010051131248474
# {'Accuracy': 0.8536296607121449, 'F1 Score': 0.881872156688966, 'Precision': 0.939250521260136, 'Recall': 0.8536296607121449}
# [inference.py]: Running inference...
# Epoch 368 - Loss: 0.45694831013679504
# {'Accuracy': 0.8568067378012229, 'F1 Score': 0.8842390590050557, 'Precision': 0.9397613711944445, 'Recall': 0.8568067378012229}
# [inference.py]: Running inference...
# Epoch 369 - Loss: 0.45880457758903503
# {'Accuracy': 0.854184150581465, 'F1 Score': 0.8823182209619577, 'Precision': 0.9391096347640487, 'Recall': 0.854184150581465}
# [inference.py]: Running inference...
# Epoch 370 - Loss: 0.4573942720890045
# {'Accuracy': 0.8568367102265916, 'F1 Score': 0.884315489614037, 'Precision': 0.9392447577902632, 'Recall': 0.8568367102265916}
# [inference.py]: Running inference...
# Epoch 371 - Loss: 0.45243892073631287
# {'Accuracy': 0.8565519721855892, 'F1 Score': 0.8841949961610189, 'Precision': 0.9394470198817296, 'Recall': 0.8565519721855892}
# [inference.py]: Running inference...
# Epoch 372 - Loss: 0.4523521959781647
# {'Accuracy': 0.8563421652080087, 'F1 Score': 0.8836000882938876, 'Precision': 0.9391113412364708, 'Recall': 0.8563421652080087}
# [inference.py]: Running inference...
# Epoch 373 - Loss: 0.45017209649086
# {'Accuracy': 0.8565669583982736, 'F1 Score': 0.8840454169462547, 'Precision': 0.9396780006863654, 'Recall': 0.8565669583982736}
# [inference.py]: Running inference...
# Epoch 374 - Loss: 0.4498462975025177
# {'Accuracy': 0.8553231027454742, 'F1 Score': 0.8829023012767, 'Precision': 0.9395624017623363, 'Recall': 0.8553231027454742}
# [inference.py]: Running inference...
# Epoch 375 - Loss: 0.44844046235084534
# {'Accuracy': 0.8565969308236423, 'F1 Score': 0.8838382600562794, 'Precision': 0.9396557018207727, 'Recall': 0.8565969308236423}
# [inference.py]: Running inference...
# Epoch 376 - Loss: 0.45346078276634216
# {'Accuracy': 0.8572862966071214, 'F1 Score': 0.8844451894899312, 'Precision': 0.9392054017186638, 'Recall': 0.8572862966071214}
# [inference.py]: Running inference...
# Epoch 377 - Loss: 0.4517737329006195
# {'Accuracy': 0.8576909243495984, 'F1 Score': 0.8850126122765698, 'Precision': 0.9401650623775366, 'Recall': 0.8576909243495984}
# [inference.py]: Running inference...
# Epoch 378 - Loss: 0.45430195331573486
# {'Accuracy': 0.8570615034168565, 'F1 Score': 0.8846408237036024, 'Precision': 0.9404238781495067, 'Recall': 0.8570615034168565}
# [inference.py]: Running inference...
# Epoch 379 - Loss: 0.45073413848876953
# {'Accuracy': 0.8563121927826399, 'F1 Score': 0.8840803108659454, 'Precision': 0.9399839934000326, 'Recall': 0.8563121927826399}
# [inference.py]: Running inference...
# Epoch 380 - Loss: 0.4520937204360962
# {'Accuracy': 0.8567917515885386, 'F1 Score': 0.8842274300102914, 'Precision': 0.9396323174384196, 'Recall': 0.8567917515885386}
# [inference.py]: Running inference...
# Epoch 381 - Loss: 0.44751349091529846
# {'Accuracy': 0.8579157175398633, 'F1 Score': 0.8851351046036354, 'Precision': 0.9401971734374541, 'Recall': 0.8579157175398633}
# [inference.py]: Running inference...
# Epoch 382 - Loss: 0.45056232810020447
# {'Accuracy': 0.8578707589018103, 'F1 Score': 0.8850828774564488, 'Precision': 0.9399067195495487, 'Recall': 0.8578707589018103}
# [inference.py]: Running inference...
# Epoch 383 - Loss: 0.45147550106048584
# {'Accuracy': 0.8582903728569716, 'F1 Score': 0.885190804965171, 'Precision': 0.939488353406476, 'Recall': 0.8582903728569716}
# [inference.py]: Running inference...
# Epoch 384 - Loss: 0.44967973232269287
# {'Accuracy': 0.8570165447788035, 'F1 Score': 0.8843500574912301, 'Precision': 0.9395253979876004, 'Recall': 0.8570165447788035}
# [inference.py]: Running inference...
# Epoch 385 - Loss: 0.44545814394950867
# {'Accuracy': 0.8561623306557967, 'F1 Score': 0.883732316330292, 'Precision': 0.9397852872458979, 'Recall': 0.8561623306557967}
# [inference.py]: Running inference...
# Epoch 386 - Loss: 0.4448837339878082
# {'Accuracy': 0.8573312552451744, 'F1 Score': 0.8844863754607442, 'Precision': 0.9394686826156863, 'Recall': 0.8573312552451744}
# [inference.py]: Running inference...
# Epoch 387 - Loss: 0.4427228271961212
# {'Accuracy': 0.8570315309914879, 'F1 Score': 0.884309312012977, 'Precision': 0.9396540937247524, 'Recall': 0.8570315309914879}
# [inference.py]: Running inference...
# Epoch 388 - Loss: 0.4426189959049225
# {'Accuracy': 0.8610028773528354, 'F1 Score': 0.8870739700964412, 'Precision': 0.9401178644371675, 'Recall': 0.8610028773528354}
# [inference.py]: Running inference...
# Epoch 389 - Loss: 0.44066867232322693
# {'Accuracy': 0.8586200695360269, 'F1 Score': 0.8855208375607337, 'Precision': 0.9397662702083448, 'Recall': 0.8586200695360269}
# [inference.py]: Running inference...
# Epoch 390 - Loss: 0.4466194212436676
# {'Accuracy': 0.8592494904687688, 'F1 Score': 0.8862253308565516, 'Precision': 0.9401573867552919, 'Recall': 0.8592494904687688}
# [inference.py]: Running inference...
# Epoch 391 - Loss: 0.44555988907814026
# {'Accuracy': 0.8603884426327778, 'F1 Score': 0.8868481898261447, 'Precision': 0.9403651647759563, 'Recall': 0.8603884426327778}
# [inference.py]: Running inference...
# Epoch 392 - Loss: 0.44386300444602966
# {'Accuracy': 0.8595042560844024, 'F1 Score': 0.8861851752142751, 'Precision': 0.9401130365790104, 'Recall': 0.8595042560844024}
# [inference.py]: Running inference...
# Epoch 393 - Loss: 0.44503068923950195
# {'Accuracy': 0.8600587459537226, 'F1 Score': 0.8864805436090949, 'Precision': 0.9401006484267701, 'Recall': 0.8600587459537226}
# [inference.py]: Running inference...
# Epoch 394 - Loss: 0.44269272685050964
# {'Accuracy': 0.8588448627262918, 'F1 Score': 0.8855394611138927, 'Precision': 0.9398690238817469, 'Recall': 0.8588448627262918}
# [inference.py]: Running inference...
# Epoch 395 - Loss: 0.4456512928009033
# {'Accuracy': 0.8598189665507733, 'F1 Score': 0.8863934888441175, 'Precision': 0.9400975138615077, 'Recall': 0.8598189665507733}
# [inference.py]: Running inference...
# Epoch 396 - Loss: 0.44570648670196533
# {'Accuracy': 0.8589947248531351, 'F1 Score': 0.8857236189308101, 'Precision': 0.9396034714823887, 'Recall': 0.8589947248531351}
# [inference.py]: Running inference...
# Epoch 397 - Loss: 0.44275224208831787
# {'Accuracy': 0.8588748351516605, 'F1 Score': 0.8858575657497496, 'Precision': 0.9406161058645076, 'Recall': 0.8588748351516605}
# [inference.py]: Running inference...
# Epoch 398 - Loss: 0.4444322884082794
# {'Accuracy': 0.8585001798345522, 'F1 Score': 0.885584150493458, 'Precision': 0.9405435553344624, 'Recall': 0.8585001798345522}
# [inference.py]: Running inference...
# Epoch 399 - Loss: 0.443548321723938
# {'Accuracy': 0.8595042560844024, 'F1 Score': 0.8863359146441359, 'Precision': 0.9404120001011069, 'Recall': 0.8595042560844024}
# [inference.py]: Running inference...

# %%
plt.figure()
X = list(range(1, n_epochs+1))
Y = total_acc
Y2 = val_total_acc 
plt.plot(X,Y2, label= "Validation")
plt.plot(X,Y, label = "Training")
plt.ylim(0,1)
plt.xlabel("Epochs")
plt.ylabel("Accuracy")
plt.title("CNN")
plt.legend()

# %%
plt.figure()
X = list(range(1, n_epochs+1))
Y = total_pre
Y2 = val_total_pre 
plt.plot(X,Y2, label= "Validation")
plt.plot(X,Y, label = "Training")
plt.ylim(0,1)
plt.xlabel("Epochs")
plt.ylabel("Precision")
plt.title("CNN")
plt.legend()

# %%
plt.figure()
X = list(range(1, n_epochs+1))
Y = total_f1
Y2 = val_total_f1 
plt.plot(X,Y2, label= "Validation")
plt.plot(X,Y, label = "Training")
plt.ylim(0,1)
plt.xlabel("Epochs")
plt.ylabel("F1")
plt.title("CNN")
plt.legend()

# %%
plt.figure()
X = list(range(1, n_epochs+1))
Y = total_rec
Y2 = val_total_rec
plt.plot(X,Y2, label= "Validation")
plt.plot(X,Y, label = "Training")
plt.ylim(0,1)
plt.xlabel("Epochs")
plt.ylabel("Recall")
plt.title("CNN")
plt.legend()

# %%
plt.figure()
X = list(range(1, n_epochs+1))
Y = total_loss
Y2 = val_total_loss 
plt.plot(X,Y2, label= "Validation")
plt.plot(X,Y, label = "Training")
plt.ylim(0,3)
plt.xlabel("Epochs")
plt.ylabel("Accuracy")
plt.title("CNN")
plt.legend()

# %%
conf_matrix= confusion_matrix(y_val,y_preds_val)
plt.figure(figsize=(8, 6))
sns.heatmap(conf_matrix, annot=True, fmt="d", cmap="Blues", cbar=False, 
            xticklabels=np.arange(conf_matrix.shape[0]), 
            yticklabels=np.arange(conf_matrix.shape[0]))

plt.title('Confusion Matrix for Test Data on Last Epoch')
plt.xlabel('Predicted Labels')
plt.ylabel('True Labels')
plt.show()

# %%
conf_matrix= confusion_matrix(y_trained,y_preds)
plt.figure(figsize=(8, 6))
sns.heatmap(conf_matrix, annot=True, fmt="d", cmap="Blues", cbar=False, 
            xticklabels=np.arange(conf_matrix.shape[0]), 
            yticklabels=np.arange(conf_matrix.shape[0]))

plt.title('Confusion Matrix for Trained Data on Last Epoch')
plt.xlabel('Predicted Labels')
plt.ylabel('True Labels')
plt.show()
